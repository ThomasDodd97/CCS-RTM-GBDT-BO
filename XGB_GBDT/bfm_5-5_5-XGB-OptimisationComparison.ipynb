# %% [markdown]
# # XGB Surrogate Model Optimisation Results

# %%
# Import generic data science modules
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## XGB Models Optimised in Isolation

# %% [markdown]
# XGB-300 Surrogate Model Optimisation Results

# %%
xgb300_prior_runs = 100   # Number of intialisation runs
xgb300_prior_xgbpred = 4.201   # XGB Prediction of % carbonates volume after init runs
xgb300_prior_rtmgt = 1.984   # RTM Ground Truth of % carbonates volume after init runs (based on optimal condition generated by the XGB model.)

xgb300_post_runs = [250,500,750,1000,1250]   # Number of purely bayesian optimisation iterations carried out
xgb300_post_xgbpred = [4.281,4.281,4.281,4.281,4.281]   # XGB predictions
xgb300_post_rtmgt = [2.317,2.317,2.317,2.317,2.317]   # RTM ground truth

xgb300_pripost_runs = [xgb300_prior_runs,250+xgb300_prior_runs,500+xgb300_prior_runs,750+xgb300_prior_runs,1000+xgb300_prior_runs,1250+xgb300_prior_runs] # total iterations carried out
xgb300_pripost_xgbpred = [xgb300_prior_xgbpred,4.281,4.281,4.281,4.281,4.281]   # XGB predictions combined init and iter runs
xgb300_pripost_rtmgt = [xgb300_prior_rtmgt,2.317,2.317,2.317,2.317,2.317]   # RTM ground truth combined init and iter runs

# %% [markdown]
# XGB-3,000 Surrogate Model Optimisation Results

# %%
xgb3000_prior_runs = 100
xgb_3000_prior_xgbpred = 2.367
xgb_3000_prior_rtmgt = 2.111

xgb3000_post_runs = [250,500,750,1000,1250]
xgb3000_post_xgbpred = [3.224,3.224,3.224,3.224,3.224]
xgb3000_post_rtmgt = [1.111,1.111,1.111,1.111,1.111]

xgb3000_pripost_runs = [xgb3000_prior_runs,250+xgb3000_prior_runs,500+xgb3000_prior_runs,750+xgb3000_prior_runs,1000+xgb3000_prior_runs,1250+xgb3000_prior_runs]
xgb3000_pripost_xgbpred = [xgb_3000_prior_xgbpred,3.224,3.224,3.224,3.224,3.224]
xgb3000_pripost_rtmgt = [xgb_3000_prior_rtmgt,1.111,1.111,1.111,1.111,1.111]

# %% [markdown]
# XGB-30,000 Surrogate Model Optimisation Results

# %%
xgb30000_prior_runs = 100
xgb_30000_prior_xgbpred = 2.431
xgb_30000_prior_rtmgt = 2.118

xgb30000_post_runs = [250,500,750,1000,1250]
xgb30000_post_xgbpred = [3.365,3.376,3.417,3.417,3.417]
xgb30000_post_rtmgt = [1.105,1.382,2.521,2.521,2.521]

xgb30000_pripost_runs = [xgb30000_prior_runs,250+xgb30000_prior_runs,500+xgb30000_prior_runs,750+xgb30000_prior_runs,1000+xgb30000_prior_runs,1250+xgb30000_prior_runs]
xgb30000_pripost_xgbpred = [xgb_30000_prior_xgbpred,3.365,3.376,3.417,3.417,3.417]
xgb30000_pripost_rtmgt = [xgb_30000_prior_rtmgt,1.105,1.382,2.521,2.521,2.521]

# %% [markdown]
# XGB-300,000 Surrogate Model Optimisation Results

# %%
xgb300000_prior_runs = 100
xgb_300000_prior_xgbpred = 2.482
xgb_300000_prior_rtmgt = 2.118

xgb300000_post_runs = [250,500,750,1000,1250]
xgb300000_post_xgbpred = [3.357,3.411,3.727,15.18,15.18]
xgb300000_post_rtmgt = [1.425,4.379,2.227,2.020,2.020]

xgb300000_pripost_runs = [xgb300000_prior_runs,250+xgb300000_prior_runs,500+xgb300000_prior_runs,750+xgb300000_prior_runs,1000+xgb300000_prior_runs,1250+xgb300000_prior_runs]
xgb300000_pripost_xgbpred = [xgb_300000_prior_xgbpred,3.357,3.411,3.727,15.18,15.18]
xgb300000_pripost_rtmgt = [xgb_300000_prior_rtmgt,1.425,4.379,2.227,2.020,2.020]

# %% [markdown]
# ## XGB Models Optimised in Sequences

# %% [markdown]
# #### CSS-DIP
#
# Cycling Surrogate System (CSS) w Discard Inherited Prior (DIP) Technique

# %%
cssdip_prior_runs = 100
cssdip_prior_model = "XGB-3,000"
ccsdip_prior_xgbpred = 2.367
cssdip_prior_rtmgt = 2.135

cssdip_post_runs = [250,500,750,1000,1250,1500]
cssdip_post_xgbmodel = ["XGB-3,000","XGB-30,000","XGB-300,000","XGB-3,000","XGB-30,000","XGB-300,000"]
cssdip_post_xgbpred = [3.224,3.396,4.595,4.595,3.365,4.149]
cssdip_post_rtmgt = [1.111,3.537,2.071,2.071,1.104,2.827]

cssdip_pripost_runs = [cssdip_prior_runs,250+cssdip_prior_runs,500+cssdip_prior_runs,750+cssdip_prior_runs,1000+cssdip_prior_runs,1250+cssdip_prior_runs,1500+cssdip_prior_runs]
cssdip_pripost_xgbmodel = ["XGB-3,000","XGB-3,000","XGB-30,000","XGB-300,000","XGB-3,000","XGB-30,000","XGB-300,000"]
cssdip_pripost_xgbpred = [ccsdip_prior_xgbpred,3.224,3.396,4.595,4.595,3.365,4.149]
cssdip_pripost_rtmgt = [cssdip_prior_rtmgt,1.111,3.537,2.071,2.071,1.104,2.827]

# %% [markdown]
# #### CSS-RIP
#
# Cycling Surrogate System (CSS) w Retain Inherited Prior (RIP) Technique

# %%
cssrip_prior_runs = 100
cssrip_prior_model = "XGB-3,000"
ccsrip_prior_xgbpred = 2.367
cssrip_prior_rtmgt = 2.135

cssrip_post_runs = [250,500,750,1000,1250,1500]
cssrip_post_xgbmodel = ["XGB-3,000","XGB-30,000","XGB-300,000","XGB-3,000","XGB-30,000","XGB-300,000"]
cssrip_post_xgbpred = [3.224,3.372,3.494,3.494,3.494,3.556]
cssrip_post_rtmgt = [1.111,1.918,2.786,2.786,2.786,5.24]

cssrip_pripost_runs = [cssrip_prior_runs,250+cssrip_prior_runs,500+cssrip_prior_runs,750+cssrip_prior_runs,1000+cssrip_prior_runs,1250+cssrip_prior_runs,1500+cssrip_prior_runs]
cssrip_pripost_xgbmodel = ["XGB-3,000","XGB-3,000","XGB-30,000","XGB-300,000","XGB-3,000","XGB-30,000","XGB-300,000"]
cssrip_pripost_xgbpred = [ccsrip_prior_xgbpred,3.224,3.372,3.494,3.494,3.494,3.556]
cssrip_pripost_rtmgt = [cssrip_prior_rtmgt,1.111,1.918,2.786,2.786,2.786,5.24]

# %% [markdown]
# #### RCSS-DIP
#
# Reverse Cycling Surrogate System (RCSS) w Discard Inherited Prior (DIP) Technique

# %%
rcssdip_prior_runs = 100
rcssdip_prior_model = "XGB-300,000"
rcssdip_prior_xgbpred = 2.482
rcssdip_prior_rtmgt = 2.118

rcssdip_post_runs = [250,500,750,1000,1250,1500]
rcssdip_post_xgbmodel = ["XGB-300,000","XGB-30,000","XGB-3,000","XGB-300,000","XGB-30,000","XGB-3,000"]
rcssdip_post_xgbpred = [3.357,3.357,3.323,3.454,4.454,3.417]
rcssdip_post_rtmgt = [1.425,1.425,2.993,3.049,3.049,2.461]

rcssdip_pripost_runs = [rcssdip_prior_runs,250+rcssdip_prior_runs,500+rcssdip_prior_runs,750+rcssdip_prior_runs,1000+rcssdip_prior_runs,1250+rcssdip_prior_runs,1500+rcssdip_prior_runs]
rcssdip_pripost_xgbmodel = ["XGB-300,000","XGB-300,000","XGB-30,000","XGB-3,000","XGB-300,000","XGB-30,000","XGB-3,000"]
rcssdip_pripost_xgbpred = [rcssdip_prior_xgbpred,3.357,3.357,3.323,3.454,4.454,3.417]
rcssdip_pripost_rtmgt = [rcssdip_prior_rtmgt,1.425,1.425,2.993,3.049,3.049,2.461]

# %% [markdown]
# #### RCSS-RIP
#
# Reverse Cycling Surrogate System (RCSS) w Retain Inherited Prior (DIP) Technique

# %%
rcssrip_prior_runs = 100
rcssrip_prior_model = "XGB-300,000"
rcssrip_prior_xgbpred = 2.482
rcssrip_prior_rtmgt = 2.118

rcssrip_post_runs = [250,500,750,1000,1250,1500]
rcssrip_post_xgbmodel = ["XGB-300,000","XGB-30,000","XGB-3,000","XGB-300,000","XGB-30,000","XGB-3,000"]
rcssrip_post_xgbpred = [3.357,3.376,3.376,3.434,7.068,7.068]
rcssrip_post_rtmgt = [1.425,1.391,1.391,2.824,2.024,2.024]

rcssrip_pripost_runs = [rcssrip_prior_runs,250+rcssrip_prior_runs,500+rcssrip_prior_runs,750+rcssrip_prior_runs,1000+rcssrip_prior_runs,1250+rcssrip_prior_runs,1500+rcssrip_prior_runs]
rcssrip_pripost_xgbmodel = ["XGB-300,000","XGB-300,000","XGB-30,000","XGB-3,000","XGB-300,000","XGB-30,000","XGB-3,000"]
rcssrip_pripost_xgbpred = [rcssrip_prior_xgbpred,3.357,3.376,3.376,3.434,7.068,7.068]
rcssrip_pripost_rtmgt = [rcssrip_prior_rtmgt,1.425,1.391,1.391,2.824,2.024,2.024]

# %% [markdown]
# ## Comparison of Optimisation Methods

# %%
# Individual Surrogate-Model Optimisation: XGBoost predictions vs iterations of optimisation
fig, ax1 = plt.subplots(1)
fig.set_figheight(5)
fig.set_figwidth(14)

ax1.scatter(xgb300_pripost_runs,xgb300_pripost_xgbpred, c="red", label="XGB-300")
ax1.plot(xgb300_pripost_runs,xgb300_pripost_xgbpred, c="red", linestyle="-", alpha=0.4)

ax1.scatter(xgb3000_pripost_runs,xgb3000_pripost_xgbpred, c="orange", label="XGB-3,000")
ax1.plot(xgb3000_pripost_runs,xgb3000_pripost_xgbpred, c="orange", linestyle="-", alpha=0.4)

ax1.scatter(xgb30000_pripost_runs,xgb30000_pripost_xgbpred, c="green", label="XGB-30,000")
ax1.plot(xgb30000_pripost_runs,xgb30000_pripost_xgbpred, c="green", linestyle="-", alpha=0.4)

ax1.scatter(xgb300000_pripost_runs,xgb300000_pripost_xgbpred, c="blue", label="XGB-300,000")
ax1.plot(xgb300000_pripost_runs,xgb300000_pripost_xgbpred, c="blue", label="XGB-300,000", linestyle="-", alpha=0.4)

ax1.set_xlabel("Total Bayesian Iterations (#)")
ax1.set_ylabel("Carbonate Precipitate Volume Fraction (%)")
ax1.set_ylim(2,5)
ax1.set_yticks(np.arange(2, 5.1, 0.5))
# ax1.set_xlim(0,1300)
# ax1.set_xticks(np.arange(0, 1301, 100))
plt.legend()

# %%
# Individual Surrogate-Model Optimisation: XGBoost predictions and RTM Ground Truths vs iterations of optimisation
fig = plt.figure()
fig.set_figheight(5)
fig.set_figwidth(14)
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)


ax1.scatter(xgb300_pripost_runs,xgb300_pripost_rtmgt, c="red", label="RTM-GT", marker="+")
ax1.plot(xgb300_pripost_runs,xgb300_pripost_rtmgt, c="red", linestyle="-.", alpha=0.4)

ax5 = ax1.twinx()
ax5.scatter(xgb300_pripost_runs,xgb300_pripost_xgbpred, c="red", label="XGB-Pred.")
ax5.plot(xgb300_pripost_runs,xgb300_pripost_xgbpred, c="red", linestyle="-", alpha=0.4)


ax2.scatter(xgb3000_pripost_runs,xgb3000_pripost_rtmgt, c="orange", label="RTM-GT", marker="+")
ax2.plot(xgb3000_pripost_runs,xgb3000_pripost_rtmgt, c="orange", linestyle="-.", alpha=0.4)

ax6 = ax2.twinx()
ax6.scatter(xgb3000_pripost_runs,xgb3000_pripost_xgbpred, c="orange", label="XGB-Pred.")
ax6.plot(xgb3000_pripost_runs,xgb3000_pripost_xgbpred, c="orange", linestyle="-", alpha=0.4)


ax3.scatter(xgb30000_pripost_runs,xgb30000_pripost_rtmgt, c="green", label="RTM-GT", marker="+")
ax3.plot(xgb30000_pripost_runs,xgb30000_pripost_rtmgt, c="green", linestyle="-.", alpha=0.4)

ax7 = ax3.twinx()
ax7.scatter(xgb30000_pripost_runs,xgb30000_pripost_xgbpred, c="green", label="XGB-Pred.")
ax7.plot(xgb30000_pripost_runs,xgb30000_pripost_xgbpred, c="green", linestyle="-", alpha=0.4)


ax4.scatter(xgb300000_pripost_runs,xgb300000_pripost_rtmgt, c="blue", label="RTM-GT", marker="+")
ax4.plot(xgb300000_pripost_runs,xgb300000_pripost_rtmgt, c="blue", linestyle="-.", alpha=0.4)

ax8 = ax4.twinx()
ax8.scatter(xgb300000_pripost_runs,xgb300000_pripost_xgbpred, c="blue", label="XGB-Pred.")
ax8.plot(xgb300000_pripost_runs,xgb300000_pripost_xgbpred, c="blue", linestyle="-", alpha=0.4)


ax.spines['top'].set_color('w')
ax.spines['bottom'].set_color('w')
ax.spines['left'].set_color('w')
ax.spines['right'].set_color('w')
ax.axes.yaxis.set_ticklabels([])
ax.axes.xaxis.set_ticklabels([])

ax1.set_title("XGB-300", loc='left')
ax2.set_title("XGB-3,000", loc='left')
ax3.set_title("XGB-30,000", loc='left')
ax4.set_title("XGB-300,000", loc='left')

ax.set_ylabel('Volume Fraction Carbonates in Fracture (%)', labelpad=20)
ax.set_xlabel('Total Bayesian Iterations (#)', labelpad=20)
# ax1.set_ylim(2,5)
# ax1.set_yticks(np.arange(2, 5.1, 1))
# ax1.set_xlim(0,1300)
# ax1.set_xticks(np.arange(0, 1301, 100))

# ax1.legend()
# ax2.legend()
# ax3.legend()
# ax4.legend()

plt.tight_layout()

# %%
# Individual Surrogate-Model Optimisation: XGBoost predictions vs iterations of optimisation
fig = plt.figure()
fig.set_figheight(5)
fig.set_figwidth(14)
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

# ax1.scatter(xgb300_pripost_runs,xgb300_pripost_rtmgt, c="red", label="RTM-GT", marker="+")
# ax1.plot(xgb300_pripost_runs,xgb300_pripost_rtmgt, c="red", linestyle="-.", alpha=0.4)

ax1.scatter(xgb300_pripost_runs,xgb300_pripost_xgbpred, c="red", label="XGB-Pred.")
ax1.plot(xgb300_pripost_runs,xgb300_pripost_xgbpred, c="red", linestyle="-", alpha=0.4)
ax1.get_xaxis().set_visible(False)
ax1.set_xlim(1.0,1400)
ax1.set_xticks(np.arange(0, 1401, 100))


# ax2.scatter(xgb3000_pripost_runs,xgb3000_pripost_rtmgt, c="orange", label="RTM-GT", marker="+")
# ax2.plot(xgb3000_pripost_runs,xgb3000_pripost_rtmgt, c="orange", linestyle="-.", alpha=0.4)

ax2.scatter(xgb3000_pripost_runs,xgb3000_pripost_xgbpred, c="orange", label="XGB-Pred.")
ax2.plot(xgb3000_pripost_runs,xgb3000_pripost_xgbpred, c="orange", linestyle="-", alpha=0.4)
ax2.get_xaxis().set_visible(False)
ax2.set_xlim(1.0,1400)
ax2.set_xticks(np.arange(0, 1401, 100))


# ax3.scatter(xgb30000_pripost_runs,xgb30000_pripost_rtmgt, c="green", label="RTM-GT", marker="+")
# ax3.plot(xgb30000_pripost_runs,xgb30000_pripost_rtmgt, c="green", linestyle="-.", alpha=0.4)

ax3.scatter(xgb30000_pripost_runs,xgb30000_pripost_xgbpred, c="green", label="XGB-Pred.")
ax3.plot(xgb30000_pripost_runs,xgb30000_pripost_xgbpred, c="green", linestyle="-", alpha=0.4)
ax3.set_xlim(1.0,1400)
ax3.set_xticks(np.arange(0, 1401, 100))


# ax4.scatter(xgb300000_pripost_runs,xgb300000_pripost_rtmgt, c="blue", label="RTM-GT", marker="+")
# ax4.plot(xgb300000_pripost_runs,xgb300000_pripost_rtmgt, c="blue", linestyle="-.", alpha=0.4)

ax4.scatter(xgb300000_pripost_runs,xgb300000_pripost_xgbpred, c="blue", label="XGB-Pred.")
ax4.plot(xgb300000_pripost_runs,xgb300000_pripost_xgbpred, c="blue", linestyle="-", alpha=0.4)
ax4.set_xlim(1.0,1400)
ax4.set_xticks(np.arange(0, 1401, 100))

ax.spines['top'].set_color('w')
ax.spines['bottom'].set_color('w')
ax.spines['left'].set_color('w')
ax.spines['right'].set_color('w')
ax.axes.yaxis.set_ticklabels([])
ax.axes.xaxis.set_ticklabels([])

ax1.set_title("XGB-300", loc='left')
ax2.set_title("XGB-3,000", loc='left')
ax3.set_title("XGB-30,000", loc='left')
ax4.set_title("XGB-300,000", loc='left')

ax.set_ylabel('Volume Fraction Carbonates in Fracture (%)', labelpad=25)
ax.set_xlabel('Total Bayesian Iterations (#)', labelpad=20)
# ax1.set_ylim(2,5)
# ax1.set_yticks(np.arange(2, 5.1, 1))
# ax1.set_xlim(0,1300)
# ax1.set_xticks(np.arange(0, 1301, 100))

# ax1.legend()
# ax2.legend()
# ax3.legend()
# ax4.legend()

plt.tight_layout()

# %%
# Cycling Surrogate-Model Optimisation: XGBoost predictions vs iterations of optimisation
fig = plt.figure()
fig.set_figheight(5)
fig.set_figwidth(14)
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

# plt.axvline(x = 100, color = 'black', linestyle = 'dashed', label="Cycle Bounds", alpha=0.4)
# plt.axvline(x = 850, color = 'black', linestyle = 'dashed', alpha=0.4)
# plt.axvline(x =1600, color = 'black', linestyle = 'dashed', alpha=0.4)

ax1.scatter(cssrip_pripost_runs,cssrip_pripost_xgbpred, c="red", label="CS-RIP",marker="x")
ax1.plot(cssrip_pripost_runs,cssrip_pripost_xgbpred, c="red", linestyle="-", alpha=0.4)
ax1.axvline(x = 100, color = 'black', linestyle = 'dotted', label="Cycle Bounds", alpha=0.4)
ax1.axvline(x = 850, color = 'black', linestyle = 'dashed', alpha=0.4)
ax1.axvline(x =1600, color = 'black', linestyle = 'dashed', alpha=0.4)
ax1.set_xlim(1.0,1650)
ax1.set_xticks(np.arange(0, 1650, 100))
ax1.get_xaxis().set_visible(False)
ax1.set_ylim(2,4)
ax1.set_yticks(np.arange(2, 4.1, 0.5))

ax2.scatter(cssdip_pripost_runs,cssdip_pripost_xgbpred, c="orange", label="CS-DIP",marker="x")
ax2.plot(cssdip_pripost_runs,cssdip_pripost_xgbpred, c="orange", linestyle="-", alpha=0.4)
ax2.axvline(x = 100, color = 'black', linestyle = 'dotted', label="Cycle Bounds", alpha=0.4)
ax2.axvline(x = 850, color = 'black', linestyle = 'dashed', alpha=0.4)
ax2.axvline(x =1600, color = 'black', linestyle = 'dashed', alpha=0.4)
ax2.set_xlim(1.0,1650)
ax2.set_xticks(np.arange(0, 1650, 100))
ax2.get_xaxis().set_visible(False)
ax2.set_ylim(2,5)
ax2.set_yticks(np.arange(2, 5.1, 0.5))

ax3.scatter(rcssrip_pripost_runs,rcssrip_pripost_xgbpred, c="green", label="RCS-RIP",marker="x")
ax3.plot(rcssrip_pripost_runs,rcssrip_pripost_xgbpred, c="green", linestyle="-", alpha=0.4)
ax3.axvline(x = 100, color = 'black', linestyle = 'dotted', label="Cycle Bounds", alpha=0.4)
ax3.axvline(x = 850, color = 'black', linestyle = 'dashed', alpha=0.4)
ax3.axvline(x =1600, color = 'black', linestyle = 'dashed', alpha=0.4)
ax3.set_xlim(1.0,1650)
ax3.set_xticks(np.arange(0, 1650, 100))
ax3.set_ylim(1,8)
ax3.set_yticks(np.arange(1, 8.1, 1.0))

ax4.scatter(rcssdip_pripost_runs,rcssdip_pripost_xgbpred, c="blue", label="RCS-DIP",marker="x")
ax4.plot(rcssdip_pripost_runs,rcssdip_pripost_xgbpred, c="blue", linestyle="-", alpha=0.4)
ax4.axvline(x = 100, color = 'black', linestyle = 'dotted', label="Cycle Bounds", alpha=0.4)
ax4.axvline(x = 850, color = 'black', linestyle = 'dashed', alpha=0.4)
ax4.axvline(x =1600, color = 'black', linestyle = 'dashed', alpha=0.4)
ax4.set_xlim(1.0,1650)
ax4.set_xticks(np.arange(0, 1650, 100))
ax4.set_ylim(2,5)
ax4.set_yticks(np.arange(2, 5.1, 0.5))

ax.spines['top'].set_color('w')
ax.spines['bottom'].set_color('w')
ax.spines['left'].set_color('w')
ax.spines['right'].set_color('w')
ax.axes.yaxis.set_ticklabels([])
ax.axes.xaxis.set_ticklabels([])

ax1.set_title("CS-RIP", loc='left')
ax2.set_title("CS-DIP", loc='left')
ax3.set_title("RCS-RIP", loc='left')
ax4.set_title("RCS-DIP", loc='left')

ax.set_ylabel('Volume Fraction Carbonates in Fracture (%)', labelpad=20)
ax.set_xlabel('Total Bayesian Iterations (#)', labelpad=20)
# ax1.set_ylim(2,5)
# ax1.set_yticks(np.arange(2, 5.1, 1))
# ax1.set_xlim(0,1300)
# ax1.set_xticks(np.arange(0, 1301, 100))

plt.tight_layout()

# %%
# Individual Surrogate-Model Optimisation: RTM Ground Truth vs iterations of optimisation
fig, ax1 = plt.subplots(1)
fig.set_figheight(5)
fig.set_figwidth(14)

plt.axhline(y = 1.1, color = 'grey', linestyle = 'dotted', label="PCF", alpha=0.4)
plt.axhline(y = 2.1, color = 'grey', linestyle = 'dashed', label="ICF", alpha=0.4)

ax1.scatter(xgb300_pripost_runs,xgb300_pripost_rtmgt, c="red", label="XGB-300")
ax1.plot(xgb300_pripost_runs,xgb300_pripost_rtmgt, c="red", linestyle="-.", alpha=0.4)

ax1.scatter(xgb3000_pripost_runs,xgb3000_pripost_rtmgt, c="orange", label="XGB-3,000")
ax1.plot(xgb3000_pripost_runs,xgb3000_pripost_rtmgt, c="orange", linestyle="-.", alpha=0.4)

ax1.scatter(xgb30000_pripost_runs,xgb30000_pripost_rtmgt, c="green", label="XGB-30,000")
ax1.plot(xgb30000_pripost_runs,xgb30000_pripost_rtmgt, c="green", linestyle="-.", alpha=0.4)

ax1.scatter(xgb300000_pripost_runs,xgb300000_pripost_rtmgt, c="blue", label="XGB-300,000")
ax1.plot(xgb300000_pripost_runs,xgb300000_pripost_rtmgt, c="blue", linestyle="-.", alpha=0.4)

ax1.set_xlabel("Total Bayesian Iterations (#)")
ax1.set_ylabel("Volume Fraction Carbonates in Fracture (%)")
ax1.set_ylim(0.5,5.0)
ax1.set_yticks(np.arange(0.5, 5.1, 0.5))
ax1.set_xlim(1.0,1400)
ax1.set_xticks(np.arange(0, 1401, 100))
plt.legend()

# %%
# Cycling Surrogate-Model Optimisation: RTM Ground Truths vs iterations of optimisation
fig, ax1 = plt.subplots(1)
fig.set_figheight(5)
fig.set_figwidth(14)

plt.axhline(y = 2.51, color = 'purple', linestyle = '-', label="XGB-30,000", alpha=0.2)
plt.axvline(x = 100, color = 'black', linestyle = 'dotted', label="Init End", alpha=0.4)
plt.axvline(x = 850, color = 'black', linestyle = 'dashed', label="Cycle End", alpha=0.4)
plt.axvline(x =1600, color = 'black', linestyle = 'dashed', alpha=0.4)

ax1.scatter(cssrip_pripost_runs,cssrip_pripost_rtmgt, c="red", label="CS-RIP", marker="x")
ax1.plot(cssrip_pripost_runs,cssrip_pripost_rtmgt, c="red", linestyle="-.", alpha=0.4)

ax1.scatter(cssdip_pripost_runs,cssdip_pripost_rtmgt, c="orange", label="CS-DIP", marker="x")
ax1.plot(cssdip_pripost_runs,cssdip_pripost_rtmgt, c="orange", linestyle="-.", alpha=0.4)

ax1.scatter(rcssrip_pripost_runs,rcssrip_pripost_rtmgt, c="green", label="RCS-RIP", marker="x")
ax1.plot(rcssrip_pripost_runs,rcssrip_pripost_rtmgt, c="green", linestyle="-.", alpha=0.4)

ax1.scatter(rcssdip_pripost_runs,rcssdip_pripost_rtmgt, c="blue", label="RCS-DIP", marker="x")
ax1.plot(rcssdip_pripost_runs,rcssdip_pripost_rtmgt, c="blue", linestyle="-.", alpha=0.4)

ax1.set_xlabel("Total Bayesian Iterations (#)")
ax1.set_ylabel("Volume Fraction Carbonates in Fracture (%)")
ax1.set_ylim(1.0,6.0)
ax1.set_yticks(np.arange(0, 6.1, 0.5))
ax1.set_xlim(1.0,1650)
ax1.set_xticks(np.arange(0, 1650, 100))
plt.legend()
